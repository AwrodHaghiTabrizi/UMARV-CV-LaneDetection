# %% [markdown]
# Import Libraries

# %%
import os
import sys
import git
from getpass import getpass

# %% [markdown]
# Configure Environment

# %%
os.environ["ENVIRONMENT"] = "windows"
os.environ["REPO_DIR"] = git.Repo(search_parent_directories=True).git.rev_parse("--show-toplevel")
os.environ["ROOT_DIR"] = os.path.abspath(os.path.join(os.getenv("REPO_DIR"), os.pardir))
os.environ["ALGORITHM_ID"] = "2y32w4o1"
os.environ["ALGORITHM_DIR"] = f"{os.getenv('REPO_DIR')}/algorithms/algorithm_{os.getenv('ALGORITHM_ID')}"

# %% [markdown]
# Import Repository Resources

# %%
sys.path.insert(0, f"{os.getenv('REPO_DIR')}/src")
from helpers import *

sys.path.insert(0, f"{os.getenv('ALGORITHM_DIR')}/src")
from methods import *
from dataset import *
from lane_detector import *

# %% [markdown]
# Download Datasets

# %%
# dbx_access_token = getpass("Enter your DropBox access token: ")

# %%
# download_datasets_from_dropbox(
#     dbx_access_token = dbx_access_token,
#     include_all_datasets = True,
#     use_thread = True
# )

# %% [markdown]
# Code

# %%
dataset = create_dataset()

# %%
show_sample_results(dataset)

# %%
test_algorithm_on_benchmarks()
# Out:
# Testing on benchmark_1 :   0%|          | 0/622 [00:00<?, ?it/s]
# Results successfully reported.
#
# benchmark_1 metrics:
# 	TN Rate: 0.9993
# 	FP Rate: 0.0007
# 	TP Rate: 0.2484
# 	FN Rate: 0.7516
# 	Accuracy: 0.9660
# 	Precision: 0.9442
# 	Recall: 0.2484
# 	Specificity: 0.9993
# 	F1 Score: 0.3933
# 	IoU Lane: 0.2448
# 	IoU Background: 0.9656
# 	Mean IoU: 0.6052
# 	Pixel Accuracy: 0.9660
# 	Mean Pixel Accuracy: 0.6052
# 	Frequency-Weighted IoU: 0.9336
# 	Dice Coefficient: 0.3933
# 	Boundary F1 Score: 0.3933
