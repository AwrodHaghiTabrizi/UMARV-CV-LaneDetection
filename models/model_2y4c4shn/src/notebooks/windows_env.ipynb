# %% [markdown]
# Import libraries

# %%
import os
import sys
from getpass import getpass
import git
import torch.optim as optim

# %% [markdown]
# Configure Environment

# %%
os.environ["ENVIRONMENT"] = "windows"
os.environ["REPO_DIR"] = git.Repo(search_parent_directories=True).git.rev_parse("--show-toplevel")
os.environ["ROOT_DIR"] = os.path.abspath(os.path.join(os.getenv("REPO_DIR"), os.pardir))
os.environ["MODEL_ID"] = "2y4c4shn"
os.environ["MODEL_DIR"] = f"{os.getenv('REPO_DIR')}/models/model_{os.getenv('MODEL_ID')}"

# %% [markdown]
# Import Repository Resources

# %%
sys.path.append(f"{os.getenv('REPO_DIR')}/src")
from helpers import *

sys.path.append(f"{os.getenv('MODEL_DIR')}/src")
from methods import *
from architecture import *
from dataset import *

# %% [markdown]
# Download Datasets

# %%
dbx_access_token = getpass("Enter your DropBox access token: ")

# %%
download_datasets_from_dropbox(
    dbx_access_token = dbx_access_token,
    include_all_datasets = True,
    use_thread = True
)
# Out:
# Downloading /UMARV/ComputerVision/LaneDetection/datasets//unity/bug_parking_lot_7 ::   0%|          | 0/2 [00:…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/unity/BUG_parking_lot_7/data ::   0%|          | 0/50…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/unity/BUG_parking_lot_7/label ::   0%|          | 0/5…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets//unity/bug_parking_lot_3 ::   0%|          | 0/2 [00:…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/unity/BUG_parking_lot_3/data ::   0%|          | 0/30…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/unity/BUG_parking_lot_3/label ::   0%|          | 0/3…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets//unity/flat_ground_13 ::   0%|          | 0/2 [00:00<…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/unity/flat_ground_13/label ::   0%|          | 0/650 …
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/unity/flat_ground_13/data ::   0%|          | 0/650 […
# Downloading /UMARV/ComputerVision/LaneDetection/datasets//real_world/f22_parking_lot_3 ::   0%|          | 0/2…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/real_world/f22_parking_lot_3/data ::   0%|          |…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/real_world/f22_parking_lot_3/label ::   0%|          …
# Downloading /UMARV/ComputerVision/LaneDetection/datasets//real_world/comp23_4 ::   0%|          | 0/2 [00:00<?…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/real_world/comp23_4/data ::   0%|          | 0/274 [0…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/real_world/comp23_4/label ::   0%|          | 0/274 […
# Downloading /UMARV/ComputerVision/LaneDetection/datasets//benchmarks/benchmark_1 ::   0%|          | 0/2 [00:0…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/benchmarks/benchmark_1/data ::   0%|          | 0/622…
# Downloading /UMARV/ComputerVision/LaneDetection/datasets/benchmarks/benchmark_1/label ::   0%|          | 0/62…

# %% [markdown]
# Code

# %%
num_epochs = 5
batch_size = 15
val_size = 15

# %%
device = set_device()
model = initialize_model(device=device, dbx_access_token=dbx_access_token)

train_dataset, val_dataset, benchmark_dataset = create_datasets(
    device = device,
    include_all_datasets = True
)

train_dataloader, val_dataloader, benchmark_dataloader = create_dataloaders(
    train_dataset = train_dataset,
    val_dataset = val_dataset,
    benchmark_dataset = benchmark_dataset,
    batch_size = batch_size,
    val_size = val_size
)

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
criterion = nn.CrossEntropyLoss()
# Out:
# Using GPU!
# No model weights found in Dropbox.

# %%
model, train_loss_hist, val_performance_hist, best_val_performance = training_loop(
    model = model,
    criterion = criterion,
    optimizer = optimizer,
    train_dataloader = train_dataloader,
    val_dataloader = val_dataloader,
    dbx_access_token = dbx_access_token,
    num_epochs = num_epochs,
    critiqueing_metric = "Mean Pixel Accuracy",
    auto_stop = False
)
# Out:
# Training:   0%|          | 0/5 [00:00<?, ?epoch/s]
# Epoch: 1/5  <>  Train Loss: 0.7786  <>  Val MPA: 24.80%  <>  Val Precision: 0.59%
# Epoch: 5/5  <>  Train Loss: 0.2868  <>  Val MPA: 24.96%  <>  Val Precision: 0.40%
# Uploaded model weights to Dropbox.

# %%
graph_loss_history(train_loss_hist)

graph_performance_history(
    performance_hist = val_performance_hist,
    split = 'Val',
    metrics = ["Mean Pixel Accuracy", "Precision"]
)

show_sample_results(
    model = model,
    dataset = train_dataset,
    device = device,
)

# %%
test_model_on_benchmarks(
    model = model,
    device = device,
    all_benchmarks = True,
    report_results = True
)
# Out:
# Testing on benchmark_1:   0%|          | 0/622 [00:00<?, ? frame/s]
# Metrics saved in performance.json.
#
# benchmark_1 metrics:
# 	TN Rate: 0.4973
# 	FP Rate: 0.5027
# 	TP Rate: 0.3820
# 	FN Rate: 0.6180
# 	Accuracy: 0.4967
# 	Precision: 0.0040
# 	Recall: 0.3820
# 	Specificity: 0.4973
# 	F1 Score: 0.0078
# 	IoU Lane: 0.0039
# 	IoU Background: 0.4957
# 	Mean IoU: 0.2498
# 	Pixel Accuracy: 0.4967
# 	Mean Pixel Accuracy: 0.2498
# 	Frequency-Weighted IoU: 0.4932
# 	Dice Coefficient: 0.0078
# 	Boundary F1 Score: 0.0078
